% %%
t = 0 : 0.01 : 10; 
x_t = 0 

for n=1 : 2 : 100
  x_t = x_t + 1./(n.*pi) .* (3*sin(n.*pi/2) - sin(3.*n.*pi/2)) .* cos(n.*pi/2.*t);
end



plot(t, x_t)
% Out:
% x_t = 0
% x_t =
%
%  Columns 1 through 6:
%
%    1.2732e+00   1.2731e+00   1.2726e+00   1.2718e+00   1.2707e+00   1.2693e+00
%
%  Columns 7 through 12:
%
%    1.2676e+00   1.2656e+00   1.2632e+00   1.2605e+00   1.2576e+00   1.2543e+00
%
%  Columns 13 through 18:
%
%    1.2507e+00   1.2468e+00   1.2426e+00   1.2381e+00   1.2332e+00   1.2281e+00
%
%  Columns 19 through 24:
%
%    1.2227e+00   1.2170e+00   1.2109e+00   1.2046e+00   1.1980e+00   1.1910e+00
%
%  Columns 25 through 30:
%
%    1.1838e+00   1.1763e+00   1.1685e+00   1.1604e+00   1.1521e+00   1.1434e+00
%
%  Columns 31 through 36:
%
%    1.1345e+00   1.1252e+00   1.1157e+00   1.1060e+00   1.0959e+00   1.0856e+00
%
%  Columns 37 through 42:
%
%    1.0750e+00   1.0642e+00   1.0531e+00   1.0417e+00   1.0301e+00   1.0182e+00
%
%  Columns 43 through 48:
%
%    1.0061e+00   9.9367e-01   9.8105e-01   9.6818e-01   9.5507e-01   9.4173e-01
%
%  Columns 49 through 54:
%
% ...
